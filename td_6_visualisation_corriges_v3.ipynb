# %% [markdown]
# # Visualisation partie 2
#
# L'objectif de ce TD est de :
# - Créer son premier widget
# - Ajouter des éléments d'interactivité à un graphique Plotly
# - transfomer le notebook de visualisation interactive en webapp (application web) avec Voilà
# - déployer et partager cette application web avec ngrok

# %% [markdown]
# # 1) Création d'un premier widget

# %% [markdown]
# a) Installation de la librairie Pywi

# %%
import sys
# !{sys.executable} -m pip install ipywidgets statsmodels
# Out:
# Requirement already satisfied: ipywidgets in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (8.0.3)
# Requirement already satisfied: statsmodels in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.13.5)
# Requirement already satisfied: ipython>=6.1.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipywidgets) (8.7.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipywidgets) (3.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipywidgets) (6.19.3)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipywidgets) (5.8.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipywidgets) (4.0.4)
# Requirement already satisfied: packaging>=21.3 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: numpy>=1.17 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: patsy>=0.5.2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: scipy>=1.3 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: pandas>=0.25 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from statsmodels) (1.5.2)
# Requirement already satisfied: appnope in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.8)
# Requirement already satisfied: nest-asyncio in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: pyzmq>=17 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (24.0.1)
# Requirement already satisfied: debugpy>=1.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: psutil in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: pickleshare in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: stack-data in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: decorator in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.36)
# Requirement already satisfied: backcall in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=0.25->statsmodels) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels) (1.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing>=1.2.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.6.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# b) Exécutez le code ci-dessous pour importer la librairie et la renommer widgets. On utilsera

# %%
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# c) La liste complète des widgets disponible est disponible à [cette adresse](https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20List.html).
#
# A l'aide de cette documentation, construisez une variable `my_int_slider` qui contiendra un widget "IntSlider" avec 5 comme valeur par défaut, 1 en minimum et 20 en maximum. On pourra laisser step égal à 1 comme niveau d'incrément.
#
# Utilisez la fonction "display" pour l'afficher.

# %%
my_int_slider = widgets.IntSlider(value=5,
                                  min=1,
                                  max=20,
                                  step=1)

display(my_int_slider)
# Out:
# IntSlider(value=5, max=20, min=1)

# %% [markdown]
# d) A quoi corresponnd le résultat de cette opération ?

# %%
my_int_slider.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'behavior',
#  'continuous_update',
#  'description',
#  'description_allow_html',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'tabbable',
#  'tooltip',
#  'value']

# %% [markdown]
# e) En déduire comment afficher la valeur du slider.
#
# Faites varier la valeur du slider et vérifier qu'en exécutant de nouveau la ligne de code, la valeur a bien changé.

# %%
print(my_int_slider.value)
# Out:
# 5

# %% [markdown]
# # 2) Création d'un User Form

# %% [markdown]
# Les widgets peuvent servir à créer des user forms pour des utilisateurs finaux.
#
# Cet exercice a pour but de construire un outil qui permet de sélectionner de sélectionner un indice boursier pour afficher un scatter plot avec l'indice d'apple AAPL.

# %% [markdown]
# a) Importez les librairies suivantes

# %%
import pandas as pd
import plotly.express as px
from ipywidgets import interact, interactive, fixed, interactive_output
import io

# %% [markdown]
# b) Dans une variable `my_upload_widget`, créez un widget de type Fileupload qui accepte l'extension .csv et un seul fichier à la fois. Puis testez l'import de ce fichier [csv exemple](https://drive.google.com/file/d/1bWMYHBP6pnxB-sztTyRe8gGMszD0GOp4/view?usp=sharing).

# %%
my_upload_widget = widgets.FileUpload(accept='.csv', multiple=False, description="Uploadez votre csv")

display(my_upload_widget)
# Out:
# FileUpload(value=(), accept='.csv', description='Uploadez votre csv')

# %% [markdown]
# c) Le données en sortie sont un peu difficile à extraire.
#
# Exécutez le code ci-dessous pour gagner du temps et posez vos questions au professeur.

# %%
#df = pd.read_csv(io.BytesIO(list(my_upload_widget.value.values())[0]["content"]))
df = pd.read_csv("stock_data.csv")
df
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %% [markdown]
# d) Représentez dans un graphique Plotly Scatter les donnnées de GOOG versus APPL avec une courbe de tendance (trendlines='ols') pour voir la corrélation entre ces deux indices.

# %%
fig = px.scatter(df, x="GOOG", y="AAPL", trendline="ols")
fig.show()

# %% [markdown]
# e) Créez une fonction `financial_scatter_widget` qui prendra en entrée les paramètres df, x et y, elle affichera le graphique créé précédemment pour les noms de colonnes x et y.

# %%
def financial_scatter_widget(df, x=None, y=None):
    fig = px.scatter(
        df,
        x=x,
        y=y,
        trendline="ols"
    )
    fig.show()

financial_scatter_widget(df, x="GOOG", y="AAPL")

# %% [markdown]
# f) L'idée est de donner la main à l'utilisateur pour choisir quel indice il souhaite vérifier la correlation avec l'indice APPL.
#
# Créez un widget de type Dropdown, qui permettra de sélectionner le nom d'une colonne du DataFrame créé.

# %%
x_dropdown = widgets.Dropdown(
    options=[col for col in df.columns if col!="date"],
    value='AAPL',
    description='AAPL vs ',
    style= {'description_width': 'initial'},
    disabled=False,
)
display(x_dropdown)
# Out:
# Dropdown(description='AAPL vs ', index=1, options=('GOOG', 'AAPL', 'AMZN', 'FB', 'NFLX', 'MSFT'), style=Descri…

# %% [markdown]
# g) A l'aide de la fonction `interact()` de widgets, faites exécutez la fonction `financial_scatter_widget` en fonction de la colonne choisie.
#
# On fixera les paramètres `df`=Le DataFrame récupéré de l'upload  et `y`="APPL" à l'aide de la fonction `fixed()`.

# %%
widgets.interact(
    financial_scatter_widget,
    df=fixed(df),
    y=fixed('AAPL'),
    x=x_dropdown
)
# Out:
# interactive(children=(Dropdown(description='AAPL vs ', index=1, options=('GOOG', 'AAPL', 'AMZN', 'FB', 'NFLX',…
# <function __main__.financial_scatter_widget(df, x=None, y=None)>

# %% [markdown]
# # 3) Réalisation du Dashboard restaurateur

# %% [markdown]
# Nous allons reprendre les visualisations faites au dernier TP et y ajouter deux éléments d'interaction, l'id du restaurant et les dates de la période sélectionnée.

# %% [markdown]
# a) Nous allons reprendre les données du TP précédent. Si besoin, vous pouvez de nouveau les téléchargez à [cette adresse](https://drive.google.com/file/d/1X5uXVFrl7SuMUKe7CJaiCmGEOhokorh2/view?usp=sharing).

# %% [markdown]
# b) Exécutez le code suivant de preprocessing des données.

# %%
df = pd.read_csv("Tiller_order_data.csv")

# Transforme les dates en format datetime
df["date_opened"] = pd.to_datetime(df["date_opened"])
df["date_closed"] = pd.to_datetime(df["date_closed"])

# Mettre en index la date d'ouverture de commande
df = df.set_index(df["date_opened"])
# Out:
# /var/folders/ng/d0bj346952q6b1m_r9plnbd00000gn/T/ipykernel_32609/824775238.py:1: DtypeWarning:
#
# Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df
# Out:
#                            id_order  id_store  id_table  id_waiter  \
# date_opened
# 2019-01-12 13:02:17+00:00  55538867      8052       NaN        NaN
# 2019-01-16 19:39:09+00:00  56035309      8052       NaN        NaN
# 2019-01-12 14:18:46+00:00  55550051      8052       NaN        NaN
# 2019-01-24 17:49:12+00:00  57000119      8052       NaN    16199.0
# 2019-01-12 15:25:06+00:00  55558817      8052       NaN        NaN
# ...                             ...       ...       ...        ...
# 2019-02-28 13:13:21+00:00  61630471      4542       NaN        NaN
# 2019-06-11 11:08:01+00:00  76772730      4542       NaN        NaN
# 2019-06-17 10:30:50+00:00  77799227      4542       NaN        NaN
# 2019-02-21 11:50:58+00:00  60627160      4542       NaN        NaN
# 2019-09-18 11:32:35+00:00  93223821      4542       NaN        NaN
#
#                            id_customer                           id_external  \
# date_opened
# 2019-01-12 13:02:17+00:00          NaN  0425716B-EFF4-41CA-AEA1-839104F36833
# 2019-01-16 19:39:09+00:00          NaN  75E41FE2-64FF-41D3-954C-A7DE4AA887EF
# 2019-01-12 14:18:46+00:00          NaN  F6051A05-C9AC-4033-BF72-BB5149B8F439
# 2019-01-24 17:49:12+00:00          NaN  B8BEEC66-1C10-48A0-B4D5-035CB5EEFE62
# 2019-01-12 15:25:06+00:00          NaN  17F0533C-2FF1-4FC5-A50D-12704C7B7A4B
# ...                                ...                                   ...
# 2019-02-28 13:13:21+00:00          NaN  C4A0AFD8-FBD7-4740-A48B-4890F46E43E2
# 2019-06-11 11:08:01+00:00          NaN  95A17B0B-22AE-43A1-8BEB-B105BF337655
# 2019-06-17 10:30:50+00:00          NaN  0E5D4843-7EA3-4D9E-9490-EB9717A0220F
# 2019-02-21 11:50:58+00:00          NaN  CE760A3B-4464-462A-AA2C-CCFEB88EEC39
# 2019-09-18 11:32:35+00:00          NaN  F004A307-C7C9-4508-A587-49ED5CF8F156
#
#                            id_device               date_opened  \
# date_opened
# 2019-01-12 13:02:17+00:00    15327.0 2019-01-12 13:02:17+00:00
# 2019-01-16 19:39:09+00:00    15327.0 2019-01-16 19:39:09+00:00
# 2019-01-12 14:18:46+00:00    15327.0 2019-01-12 14:18:46+00:00
# 2019-01-24 17:49:12+00:00    15327.0 2019-01-24 17:49:12+00:00
# 2019-01-12 15:25:06+00:00    15327.0 2019-01-12 15:25:06+00:00
# ...                              ...                       ...
# 2019-02-28 13:13:21+00:00     7411.0 2019-02-28 13:13:21+00:00
# 2019-06-11 11:08:01+00:00     7411.0 2019-06-11 11:08:01+00:00
# 2019-06-17 10:30:50+00:00     7411.0 2019-06-17 10:30:50+00:00
# 2019-02-21 11:50:58+00:00     7411.0 2019-02-21 11:50:58+00:00
# 2019-09-18 11:32:35+00:00     7411.0 2019-09-18 11:32:35+00:00
#
#                                         date_closed  \
# date_opened
# 2019-01-12 13:02:17+00:00 2019-01-12 19:58:38+00:00
# 2019-01-16 19:39:09+00:00 2019-01-16 22:10:50+00:00
# 2019-01-12 14:18:46+00:00 2019-01-12 19:50:32+00:00
# 2019-01-24 17:49:12+00:00 2019-01-24 21:58:59+00:00
# 2019-01-12 15:25:06+00:00 2019-01-12 19:21:03+00:00
# ...                                             ...
# 2019-02-28 13:13:21+00:00 2019-02-28 13:38:45+00:00
# 2019-06-11 11:08:01+00:00 2019-06-11 11:10:26+00:00
# 2019-06-17 10:30:50+00:00 2019-06-17 10:32:45+00:00
# 2019-02-21 11:50:58+00:00 2019-02-21 11:51:56+00:00
# 2019-09-18 11:32:35+00:00 2019-09-18 11:39:38+00:00
#
#                                              dim_name dim_status  dim_type  \
# date_opened
# 2019-01-12 13:02:17+00:00                     vincent     CLOSED         1
# 2019-01-16 19:39:09+00:00  frere et soeur avec pierre     CLOSED         1
# 2019-01-12 14:18:46+00:00                      rachel     CLOSED         1
# 2019-01-24 17:49:12+00:00                  Groupe PEL     CLOSED         1
# 2019-01-12 15:25:06+00:00                remi et date     CLOSED         1
# ...                                               ...        ...       ...
# 2019-02-28 13:13:21+00:00                         NaN     CLOSED         1
# 2019-06-11 11:08:01+00:00                         NaN     CLOSED         1
# 2019-06-17 10:30:50+00:00                         NaN     CLOSED         1
# 2019-02-21 11:50:58+00:00                         NaN     CLOSED         1
# 2019-09-18 11:32:35+00:00                         NaN     CLOSED         1
#
#                           dim_comment    dim_source  m_nb_customer  \
# date_opened
# 2019-01-12 13:02:17+00:00         NaN   Tiller iPAD              1
# 2019-01-16 19:39:09+00:00         NaN   Tiller iPAD              2
# 2019-01-12 14:18:46+00:00         NaN   Tiller iPAD              1
# 2019-01-24 17:49:12+00:00         NaN  tiller-order              3
# 2019-01-12 15:25:06+00:00         NaN   Tiller iPAD              2
# ...                               ...           ...            ...
# 2019-02-28 13:13:21+00:00         NaN   Tiller iPAD              1
# 2019-06-11 11:08:01+00:00         NaN   Tiller iPAD              1
# 2019-06-17 10:30:50+00:00         NaN   Tiller iPAD              1
# 2019-02-21 11:50:58+00:00         NaN   Tiller iPAD              1
# 2019-09-18 11:32:35+00:00         NaN   Tiller iPAD              1
#
#                            m_cached_payed  m_cached_price
# date_opened
# 2019-01-12 13:02:17+00:00            45.5            45.5
# 2019-01-16 19:39:09+00:00            49.8            49.8
# 2019-01-12 14:18:46+00:00            27.4            27.4
# 2019-01-24 17:49:12+00:00            60.0            60.0
# 2019-01-12 15:25:06+00:00            39.9            39.9
# ...                                   ...             ...
# 2019-02-28 13:13:21+00:00            23.0            23.0
# 2019-06-11 11:08:01+00:00            26.0            26.0
# 2019-06-17 10:30:50+00:00            29.0            29.0
# 2019-02-21 11:50:58+00:00            32.0            32.0
# 2019-09-18 11:32:35+00:00            17.0            17.0
#
# [117304 rows x 17 columns]

# %% [markdown]
# c) Exécutez le code ci-dessous qui détermine l'id du restaurant et les dates de la période souhaitée. Ce sont ces paramètres que nous allons rendre sélectionnables grâce aux widgets.

# %%
id_store = 8052
date_debut = "2019-10-01"
date_fin = "2021-12-31"

df_store = df[(df.id_store == id_store) & (df.date_opened >= date_debut) & (df.date_closed < date_fin)]
df_store.shape
# Out:
# (2703, 17)

# %% [markdown]
# d) Changez le code précédent en utilisant deux widgets, un dropdown menu pour choisir le restaurant et un date picker pour choisir la date de début et de fin de la période qu'on souhaite analyser.

# %% [markdown]
# Créez la variable `id_store_dropdown` avec un widget de type Dropdown :

# %%
id_store_dropdown = widgets.Dropdown(
    options=df.id_store.unique(),
    value=8052,
    description='Id restaurateur',
    style= {'description_width': 'initial'},
    disabled=False,
)

# %%
display(id_store_dropdown)
# Out:
# Dropdown(description='Id restaurateur', options=(8052, 8347, 8283, 9084, 4337, 360, 1796, 7965, 6293, 4542), s…

# %% [markdown]
# Créez la variable `date_debut_picker` avec un widget de type DatePicker :

# %%
date_debut_picker = widgets.DatePicker(
    description='Date début',
    disabled=False
)

# %%
display(date_debut_picker)
# Out:
# DatePicker(value=None, description='Date début', step=1)

# %% [markdown]
# Créez la variable `date_fin_picker` avec un widget de type DatePicker :

# %%
date_fin_picker = widgets.DatePicker(
    description='Date fin',
    disabled=False
)

# %%
display(date_fin_picker)
# Out:
# DatePicker(value=None, description='Date fin', step=1)

# %% [markdown]
# e) Exécutez le code suivant pour transformer toutes les visualisations réalisées au TP précédent en fonctions

# %%
import plotly.graph_objects as go

def revenue_over_time(df_store):
    df_revenue = df_store[df_store.dim_status=="CLOSED"].resample("D").m_cached_payed.sum()

    fig = px.line(df_revenue,
                  y="m_cached_payed",
                  title="Chiffre d'affaire au cours du temps")
    fig.update_xaxes(
        rangeselector=dict(
            buttons=list([
                dict(count=7, label="Last 7days", step="day", stepmode="backward"),
                dict(count=1, label="1m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="YTD", step="year", stepmode="todate"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        )
    )
    fig.show()

def clients_by_time(df_store):
    df_revenue = df_store[df_store.dim_status=="CLOSED"].resample("D").m_cached_payed.sum()
    df_nb_customer = df_store[df_store.dim_status=="CLOSED"].resample("D")["m_nb_customer"].sum()

    df_average_basket = df_revenue / df_nb_customer

    fig_panier_moyen = go.Scatter(x=df_average_basket.index,
                                  y=df_average_basket,
                                  name="panier moyen",
                                  mode="lines",
                                  line_color="#000000")

    fig = px.bar(df_nb_customer,
                 title="Nombre de clients au cours du temps")
    fig.add_trace(fig_panier_moyen)
    fig.update_xaxes(tickformat="%d/%m/%Y")
    fig.update_xaxes(
        rangeselector=dict(
            buttons=list([
                dict(count=1, label="1m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="YTD", step="year", stepmode="todate"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        )
    )
    fig.show()

def best_staff(df_store):
    df_store.loc[df_store["id_waiter"].isnull(), "id_waiter"] = "unknown"

    df_waiter = df_store.groupby("id_waiter", as_index=False)["m_cached_payed"].sum()

    fig = px.pie(
        df_waiter,
        names='id_waiter',
        values='m_cached_payed',
        color='id_waiter',
        title = 'Répartition des commandes non enregistrées par un serveur'
    )
    fig.update_traces(
        textinfo='percent+label'
    )
    fig.show()

# %% [markdown]
# f) Faîtes intéragir les widgets précédemment créés, via la fonction 'interact', avec la fonction 'display_dash'.
#
# Cette fonction 'display_dash' filtre le dataframe initial en fonction des valeurs précisées dans les trois widgets, et appelle ensuite les visualisations ci-dessus pour les afficher à partir du dataframe filtré.
#
# Vous devez donc, dans cette fonction 'display_dash' :
# - filtrer le dataframe iniitial (df) en fonction des valeurs des widgets id_store_dropdown, date_debut_picker et date_fin_picker
# - appeler les fonctions revenue_over_time, clients_over_time et best_staff

# %%
def display_dash(df, id_store_dropdown, date_debut_picker, date_fin_picker):
    df_filtered = df[df.id_store == id_store_dropdown]
    if date_debut_picker is not None:
        df_filtered = df_filtered[df_filtered.date_opened >= str(date_debut_picker)]
    if date_fin_picker is not None:
        df_filtered = df_filtered[df_filtered.date_opened < str(date_fin_picker)]
    revenue_over_time(df_filtered)
    clients_by_time(df_filtered)
    best_staff(df_filtered)

# %%
widgets.interact(
    display_dash,
    df=fixed(df),
    id_store_dropdown=id_store_dropdown,
    date_debut_picker=date_debut_picker,
    date_fin_picker=date_fin_picker
)
# Out:
# interactive(children=(Dropdown(description='Id restaurateur', options=(8052, 8347, 8283, 9084, 4337, 360, 1796…
# <function __main__.display_dash(df, id_store_dropdown, date_debut_picker, date_fin_picker)>

# %% [markdown]
# g) Organisez votre dashboard en utilisant HBox et VBox de la librairie widgets.
#
# Ils permettent de gérer l'agencement des différentes visualisation :
# - placer sur la première ligne le widget : id_store_dropdown
# - placer sur la seconde ligne les widgets date_debut_picker et date_fin_picker

# %%
from ipywidgets import HBox, VBox

# %%
ui = VBox([
    id_store_dropdown,
    HBox([
        date_debut_picker,
        date_fin_picker
    ])
])

# %%
ui
# Out:
# VBox(children=(Dropdown(description='Id restaurateur', options=(8052, 8347, 8283, 9084, 4337, 360, 1796, 7965,…

# %% [markdown]
# h) utiliser maintenant la fonction ['interactive_output'](https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html#More-control-over-the-user-interface:-interactive_output).
# Cette fonction permet d'être plus flexible sur la disposition des widgets.

# %%
out = interactive_output(
    display_dash,
    {
        'df': fixed(df),
        'id_store_dropdown': id_store_dropdown,
        'date_debut_picker': date_debut_picker,
        'date_fin_picker': date_fin_picker
    }
)
display(ui, out)
# Out:
# VBox(children=(Dropdown(description='Id restaurateur', options=(8052, 8347, 8283, 9084, 4337, 360, 1796, 7965,…
# Output()

# %% [markdown]
# i) Vérifiez que tout fonctionne bien en changeant l'id du restaurant et les dates de la période.
# Si tout fonctionne, Bravo vous avez créé votre premier dashboard sous Python !

# %% [markdown]
# # 4) Transformation du notebook en application web avec Voilà

# %% [markdown]
# Maintenant que nous avons l'ensemble des éléments pour notre dashboard utilisateur, nous allons convertir notre notebook en application web pour qu'on puisse l'exécuter en local et pouvoir interragir avec les éléments.

# %% [markdown]
# a) Commencez par installer [Voila](https://github.com/voila-dashboards/voila)

# %%
import sys
# !{sys.executable} -m pip install voila
# Out:
# Requirement already satisfied: voila in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.5.4)
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from voila) (7.4.8)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from voila) (2.16.5)
# Requirement already satisfied: traitlets<6,>=5.0.3 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from voila) (5.8.0)
# Requirement already satisfied: jupyter-server<3,>=2.0.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from voila) (2.7.3)
# Requirement already satisfied: websockets>=9.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from voila) (11.0.3)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from voila) (7.2.7)
# Requirement already satisfied: nbclient<0.8,>=0.4.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from voila) (0.7.2)
# Requirement already satisfied: jupyter-core>=4.11.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from voila) (5.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-client<9,>=7.4.4->voila) (2.8.2)
# Requirement already satisfied: entrypoints in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-client<9,>=7.4.4->voila) (0.4)
# Requirement already satisfied: pyzmq>=23.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-client<9,>=7.4.4->voila) (24.0.1)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-client<9,>=7.4.4->voila) (1.5.6)
# Requirement already satisfied: tornado>=6.2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-client<9,>=7.4.4->voila) (6.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-core>=4.11.0->voila) (2.6.0)
# Requirement already satisfied: anyio>=3.1.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (3.6.2)
# Requirement already satisfied: terminado>=0.8.3 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.17.1)
# Requirement already satisfied: argon2-cffi in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (21.3.0)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (5.7.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (1.8.2)
# Requirement already satisfied: jupyter-events>=0.6.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.7.0)
# Requirement already satisfied: overrides in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (7.4.0)
# Requirement already satisfied: jinja2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (3.1.2)
# Requirement already satisfied: jupyter-server-terminals in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.4.4)
# Requirement already satisfied: websocket-client in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (1.4.2)
# Requirement already satisfied: packaging in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (21.3)
# Requirement already satisfied: prometheus-client in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.15.0)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.19.1)
# Requirement already satisfied: requests>=2.28 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.28.1)
# Requirement already satisfied: json5>=0.9.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.10)
# Requirement already satisfied: babel>=2.10 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: bleach in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (5.0.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (0.2.2)
# Requirement already satisfied: defusedxml in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.13.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (4.11.1)
# Requirement already satisfied: tinycss2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (1.2.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.0.4)
# Requirement already satisfied: idna>=2.8 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.3.0->voila) (2022.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (0.10.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (23.1.0)
# Requirement already satisfied: referencing>=0.28.4 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (0.30.2)
# Requirement already satisfied: pyyaml>=5.3 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.0.0->voila) (6.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.0.0->voila) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.0.0->voila) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.0.0->voila) (0.1.4)
# Requirement already satisfied: fastjsonschema in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.0.0->voila) (2.16.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from packaging->jupyter-server<3,>=2.0.0->voila) (3.0.9)
# Requirement already satisfied: six>=1.5 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client<9,>=7.4.4->voila) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.3.0->voila) (1.26.13)
# Requirement already satisfied: ptyprocess in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.0.0->voila) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.0.0->voila) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from bleach->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: webcolors>=1.11 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (1.13)
# Requirement already satisfied: uri-template in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (1.3.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (2.4)
# Requirement already satisfied: fqdn in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (1.5.1)
# Requirement already satisfied: isoduration in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (20.11.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.0.0->voila) (1.15.1)
# Requirement already satisfied: pycparser in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.0.0->voila) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /Users/xtof/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from isoduration->jsonschema>=3.0.1->jupyterlab-server<3,>=2.3.0->voila) (1.2.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# b) Marquez toutes les cellules pour ne garder que les cellules de l'exercice 3, afin de n'afficher que le dashboard de cette partie.
#
# Pour ce faire, vous devrez taggez au préalable les cellules avec un nom de tag. On choisira le tag `hide` dans cet exemple.
#
# Pour cela, cliquez sur "Affichage"-> "Barre d'outil de cellule" -> "Tags"
#
# (Ah... attendez, c'est déjà fait ! On vous fait gagner du temps)

# %% [markdown]
# c) Depuis un terminal, lancez la commande :
# ```
# voila --TagRemovePreprocessor.remove_cell_tags hide ce_notebook.ipynb
# ```

# %% [markdown]
# # 5) Déploiement de la webapp avec ngrok

# %% [markdown]
# On souhaite maintenant pouvoir partager notre webapp sans pour autant la déployer sur serveur sur un autre ordinateur.
#
# Pour cela, nous allons utiliser la librairie ngrok dont la documentation peut être consultée à [cette adresse](https://voila.readthedocs.io/en/stable/deploy.html). Mais nous allons vous guider dans la suite de cette partie.

# %% [markdown]
# a) Installer [ngrok](https://ngrok.com/download)
#
# https://ngrok.com/download

# %% [markdown]
# b) Unzippez l'archive, puis authentifiez vous avec votre token :
#
# ```./ngrok authtoken <token>```

# %% [markdown]
# c) Assurez-vous qu'une webapp voilà est déjà lancée en local (cf : commande voila ci-dessus)

# %% [markdown]
# d) Lancer un tunnel sur le port 8866 :
#
# ```./ngrok http 8866```

# %% [markdown]
# e) Cliquez sur le lien affiché dans le terminal (```Forwarding```).
# Vous pouvez envoyer cette url à votre voisin, il pourra acceder à votre webapp !

# %% [markdown]
# # [Bonus] Déploiement d'une webapp avec Binder
#
# Pour pouvoir utiliser [Binder](https://jupyter.org/binder), il faut au préalable avoir pushé son notebook dans un repo git et avoir rajouté un fichier 'requirements.txt' contenant les librairies nécessaires pour faire tourner votre projet.
#
# Ensuite, il suffit d'aller sur https://mybinder.org/ et :
# - dans 'GitHub', copier coller l'URL de votre projet git
# - dans 'Path to a notebook file (optional)', écrivez 'voila/render/ce_notebook.ipynb' en précisant bien 'URL' au lieu de 'File'. Celà permet de spécifier à Binder qu'il faut directement utiliser Voila pour créer la webapp.
#
# Cliquez ensuite sur 'lauch'. Une image docker de votre projet sera créer grace au fichier 'requirements.txt'. Vous aurez ensuite un lien pour lancer un conteneur docker autonome qui vous permettra d'acceder à votre application web. Pour chaque utilisateur utilisant ce lien, un conteneur docker sera créé.
